# %%
import duckdb as db
import pandas as pd

def sql(query, database = "../data/database.duckdb"):
    con = db.connect(database)
    res = con.execute(query).df()
    con.close()
    return res

# %%
sql("show tables")
# Out:
#                name
# 0       name_basics
# 1        title_akas
# 2      title_basics
# 3        title_crew
# 4  title_principals
# 5     title_ratings
# 6              tmdb

# %%
sql("select * from title_basics limit 1")
# Out:
#       tconst titleType primaryTitle originalTitle  isAdult startYear endYear  \
# 0  tt0000009     movie   Miss Jerry    Miss Jerry        0      1894      \N
#
#   runtimeMinutes   genres
# 0             45  Romance

# %%
sql("select * from title_crew limit 1")
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N

# %%
sql("""select * from name_basics 
    where primaryProfession like '%director%'
    and birthYear not like '%\\N%'
    """)
# Out:
#            nconst          primaryName birthYear deathYear  \
# 0       nm0000005       Ingmar Bergman      1918      2007
# 1       nm0000008        Marlon Brando      1924      2004
# 2       nm0000009       Richard Burton      1925      1984
# 3       nm0000010         James Cagney      1899      1986
# 4       nm0000018         Kirk Douglas      1916      2020
# ...           ...                  ...       ...       ...
# 102832  nm9990476  Peerada Meemalayath      1994        \N
# 102833  nm9990940     Emma-Marie Fusco      2001        \N
# 102834  nm9992905            Hepi Mita      1986        \N
# 102835  nm9992946   Christoph Blaschke      1993        \N
# 102836  nm9993379      Fanny Hozleiter      1988        \N
#
#                                         primaryProfession  \
# 0                                   writer,director,actor
# 1                                   actor,director,writer
# 2                                 actor,producer,director
# 3                                 actor,director,producer
# 4                                 actor,producer,director
# ...                                                   ...
# 102832                  actress,director,costume_designer
# 102833                   actress,cinematographer,director
# 102834                         director,camera_department
# 102835  assistant_director,miscellaneous,camera_depart...
# 102836                            director,actress,writer
#
#                                     knownForTitles
# 0          tt0050986,tt0069467,tt0050976,tt0083922
# 1          tt0078788,tt0068646,tt0047296,tt0070849
# 2          tt0061184,tt0087803,tt0059749,tt0057877
# 3          tt0029870,tt0031867,tt0042041,tt0034236
# 4          tt0043338,tt0080736,tt0054331,tt0049456
# ...                                            ...
# 102832  tt9742936,tt13186480,tt14036168,tt12831094
# 102833                                  tt13728608
# 102834                         tt8742574,tt1504286
# 102835   tt9738336,tt3900614,tt11650404,tt10172548
# 102836                         tt8743182,tt8141342
#
# [102837 rows x 6 columns]

# %%
sql("select * from title_ratings limit 1")
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2157

# %%
sql(""" select * from tmdb t 
    left join title_basics tb on t.imdb_id = tb.tconst 
    left join title_ratings tr on tb.tconst = tr.tconst
    where tb.startYear > '1960'
    and budget > '0'
    and adult is false
    and averageRating > 5
    and numVotes > 1000
    order by budget desc

    """)
# Out:
#       adult                     backdrop_path     budget  \
# 0     False  /uQNB6ccHv4uR21643xqyhK5Dk6W.jpg  579330426
# 1     False  /8rpDcsfLJypbO6vREc0547VKqEv.jpg  460000000
# 2     False  /uzIGtyS6bbnJzGsPL93WCF1FWm8.jpg  379000000
# 3     False  /6YwkGolwdOMNpbTOmLjoehlVWs5.jpg  365000000
# 4     False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg  356000000
# ...     ...                               ...        ...
# 9866  False  /ggOMmWtYiKt1KQiXarHsSpo1f1d.jpg          1
# 9867  False  /o2E1IvEsQS4gWcAccs7X37xzwzV.jpg          1
# 9868  False  /oFEfrMKko2tlkYT2rNdcU4TF2ev.jpg          1
# 9869  False  /xeN6uxr1ao3wBjvjn86mThQJ5ku.jpg          1
# 9870  False  /7FgrIVL3FGfMzUA5KYiK7LA39Oh.jpg          1
#
#                                           genres  \
# 0         ['Action', 'Thriller', 'War', 'Drama']
# 1     ['Science Fiction', 'Adventure', 'Action']
# 2             ['Adventure', 'Action', 'Fantasy']
# 3     ['Action', 'Adventure', 'Science Fiction']
# 4     ['Adventure', 'Science Fiction', 'Action']
# ...                                          ...
# 9866            ['Thriller', 'Horror', 'Action']
# 9867    ['Drama', 'Family', 'Comedy', 'Romance']
# 9868          ['Family', 'Fantasy', 'Adventure']
# 9869                                   ['Drama']
# 9870                                   ['Drama']
#
#                                                homepage      id    imdb_id  \
# 0                                                  None  460555  tt6878882
# 1     https://www.avatar.com/movies/avatar-the-way-o...   76600  tt1630029
# 2     https://movies.disney.com/pirates-of-the-carib...    1865  tt1298650
# 3     http://marvel.com/movies/movie/193/avengers_ag...   99861  tt2395427
# 4        https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# ...                                                 ...     ...        ...
# 9866                        http://www.hushmovie.co.uk/   20034  tt1093369
# 9867         https://svf.in/movie/bojhena-shey-bojhena/  244537  tt2597126
# 9868                                               None   64313  tt0119550
# 9869                                               None   37532  tt0139615
# 9870         http://www.atmo.se/film-and-tv/shemonkeys/   78646  tt1827358
#
#      original_language                               original_title  \
# 0                   zh                                         红海行动
# 1                   en                     Avatar: The Way of Water
# 2                   en  Pirates of the Caribbean: On Stranger Tides
# 3                   en                      Avengers: Age of Ultron
# 4                   en                            Avengers: Endgame
# ...                ...                                          ...
# 9866                en                                         Hush
# 9867                bn                         Bojhena Shey Bojhena
# 9868                en                                 Little Ghost
# 9869                en                                         Slam
# 9870                sv                                  Apflickorna
#
#                                                overview  ...  \
# 0     A squad of the Jiaolong Commando Unit - Sea Dr...  ...
# 1     Set more than a decade after the events of the...  ...
# 2     Captain Jack Sparrow crosses paths with a woma...  ...
# 3     When Tony Stark tries to jumpstart a dormant p...  ...
# 4     After the devastating events of Avengers: Infi...  ...
# ...                                                 ...  ...
# 9866  A young couple on a motorway journey are drawn...  ...
# 9867  A horrible accident takes place between two bu...  ...
# 9868  While on location in a spooky Italian villa wi...  ...
# 9869  Slam tells the story of Ray Joshua, an origina...  ...
# 9870  When Emma meets Cassandra, they initiate a rel...  ...
#
#                                      primaryTitle  \
# 0                               Operation Red Sea
# 1                        Avatar: The Way of Water
# 2     Pirates of the Caribbean: On Stranger Tides
# 3                         Avengers: Age of Ultron
# 4                               Avengers: Endgame
# ...                                           ...
# 9866                                         Hush
# 9867                         Bojhena Shey Bojhena
# 9868                                 Little Ghost
# 9869                                         Slam
# 9870                                  She Monkeys
#
#                                     originalTitle isAdult startYear  endYear  \
# 0                              Hong hai xing dong       0      2018       \N
# 1                        Avatar: The Way of Water       0      2022       \N
# 2     Pirates of the Caribbean: On Stranger Tides       0      2011       \N
# 3                         Avengers: Age of Ultron       0      2015       \N
# 4                               Avengers: Endgame       0      2019       \N
# ...                                           ...     ...       ...      ...
# 9866                                         Hush       0      2008       \N
# 9867                         Bojhena Shey Bojhena       0      2012       \N
# 9868                                 Little Ghost       0      1997       \N
# 9869                                         Slam       0      1998       \N
# 9870                                  Apflickorna       0      2011       \N
#
#       runtimeMinutes                  genres_1   tconst_1 averageRating  \
# 0                142     Action,Drama,Thriller  tt6878882           6.6
# 1                192  Action,Adventure,Fantasy  tt1630029           7.5
# 2                136  Action,Adventure,Fantasy  tt1298650           6.6
# 3                141   Action,Adventure,Sci-Fi  tt2395427           7.3
# 4                181   Action,Adventure,Sci-Fi  tt4154796           8.4
# ...              ...                       ...        ...           ...
# 9866              91           Horror,Thriller  tt1093369           6.0
# 9867             145      Comedy,Drama,Romance  tt2597126           7.7
# 9868              90            Family,Fantasy  tt0119550           5.9
# 9869             100                     Drama  tt0139615           7.0
# 9870              84               Drama,Sport  tt1827358           5.5
#
#      numVotes
# 0        8332
# 1      534303
# 2      586870
# 3      960418
# 4     1357768
# ...       ...
# 9866     7384
# 9867     2884
# 9868     2083
# 9869     2526
# 9870     2437
#
# [9871 rows x 37 columns]

# %%
sql(
    """ 
    select primaryTitle as Title,
    startYear as Year,
    runtimeMinutes as Runtime,
    nb.primaryName as Director
    from title_basics tb
    join title_akas ta on tconst = titleId
    join title_crew using (tconst)
    join name_basics nb on directors = nconst
    where region like 'US'
    and Year > '1950'
    and runtime > '60'
    LIMIT 
"""
)
# Out:
#                                                     Title  Year Runtime  \
# 0                                           Autumn Sonata  1978      99
# 1                                       Short Cut to Hell  1957      89
# 2                                                   Posse  1975      92
# 3                                     Orchestra Rehearsal  1978      72
# 4                                  The Trouble with Harry  1955      99
# ...                                                   ...   ...     ...
# 188336                          Vintage Erotica Anno 1920  2006      90
# 188337  Stolen Innocence: India's Untold Story of Huma...  2017      88
# 188338                                           Prathama  1993      \N
# 188339                                        The Deposit  2019      90
# 188340                                       The Mountain  2025      \N
#
#                         Director
# 0                 Ingmar Bergman
# 1                   James Cagney
# 2                   Kirk Douglas
# 3               Federico Fellini
# 4               Alfred Hitchcock
# ...                          ...
# 188336            Max van Norden
# 188337               Chris Davis
# 188338              Prabir Mitra
# 188339  Ásthildur Kjartansdóttir
# 188340  Ásthildur Kjartansdóttir
#
# [188341 rows x 4 columns]

# %%
sql("""    
    
    select distinct
    Tconst as tconst,
    tb.primaryTitle as Title,
    tb.genres as Genres,
    startYear as Year,
    runtimeMinutes as Runtime,
    nb.primaryName as Director,
    tr.averageRating as Rating,
    tr.numVotes as Votes,
    t.Budget as Budget,
    t.Revenue as Revenue,
    production_companies_name as ProductionCompanies,
    production_companies_country as ProductionCountries,
    t.poster_path as Poster
    from title_basics tb
    join title_akas ta on tconst = titleId
    join title_crew using (tconst)
    join name_basics nb on directors = nconst
    join tmdb t on t.imdb_id = tb.tconst
    join title_ratings tr on tb.tconst = tr.tconst
    
    ORDER BY Revenue desc
    
    """)
# Out:
#             tconst                                       Title  \
# 0        tt0499549                                      Avatar
# 1        tt1630029                    Avatar: The Way of Water
# 2        tt0120338                                     Titanic
# 3        tt2488496  Star Wars: Episode VII - The Force Awakens
# 4       tt10872600                     Spider-Man: No Way Home
# ...            ...                                         ...
# 172404   tt9784456                         The Kissing Booth 2
# 172405   tt9789808                              African Mirror
# 172406   tt9799992                                 Sang Krasue
# 172407   tt9808842                             Speak Your Mind
# 172408   tt9808874                                   Back Home
#
#                           Genres  Year Runtime                Director  \
# 0       Action,Adventure,Fantasy  2009     162           James Cameron
# 1       Action,Adventure,Fantasy  2022     192           James Cameron
# 2                  Drama,Romance  1997     194           James Cameron
# 3        Action,Adventure,Sci-Fi  2015     138             J.J. Abrams
# 4       Action,Adventure,Fantasy  2021     148               Jon Watts
# ...                          ...   ...     ...                     ...
# 172404            Comedy,Romance  2020     134          Vince Marcello
# 172405       Documentary,History  2019      84         Mischa Hedinger
# 172406      Drama,Horror,Romance  2019     122    Sitisiri Mongkolsiri
# 172407              Comedy,Drama  2019     105             Cyrus Baetz
# 172408                     Drama  2019     105  Magdalena Lazarkiewicz
#
#         Rating    Votes     Budget     Revenue  \
# 0          7.9  1431034  237000000  2923706026
# 1          7.5   534303  460000000  2319331580
# 2          7.9  1339709  200000000  2264162353
# 3          7.7   999995  245000000  2068223624
# 4          8.2   952090  200000000  1921847111
# ...        ...      ...        ...         ...
# 172404     5.7    40948          0           0
# 172405     6.3       37          0           0
# 172406     6.4     2337    1200000           0
# 172407     3.7       44          0           0
# 172408     6.0      107          0           0
#
#                                       ProductionCompanies  \
# 0       ['Dune Entertainment', 'Lightstorm Entertainme...
# 1       ['20th Century Studios', 'Lightstorm Entertain...
# 2       ['Paramount', '20th Century Fox', 'Lightstorm ...
# 3                         ['Lucasfilm Ltd.', 'Bad Robot']
# 4       ['Marvel Studios', 'Pascal Pictures', 'Columbi...
# ...                                                   ...
# 172404                           ['Komixx Entertainment']
# 172405                              ['ton und bild GmbH']
# 172406  ['CJ Major Entertainment', 'M Pictures', 'Tran...
# 172407                                                 []
# 172408  ['Lambros ZIOTAS (Argomedia)', 'Piramida', 'Dr...
#
#                          ProductionCountries                            Poster
# 0                   ['US', 'US', 'US', 'GB']  /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 1                                       None  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg
# 2                         ['US', 'US', 'US']  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 3                                       None  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 4                         ['US', 'US', 'US']  /uJYYizSuA9Y3DCs0qS4qWvHfZg4.jpg
# ...                                      ...                               ...
# 172404                                ['GB']  /mb7wQv0adK3kjOUr9n93mANHhPJ.jpg
# 172405                                  ['']  /vsOKiqA2FiMJA1FWmMC1nLdqeEx.jpg
# 172406            ['TH', 'TH', 'TH', '', '']  /x1IrVoc9Q7Hn6NKP4jq77jN1cUU.jpg
# 172407                                    []  /btRsrY0PUW1ApfRNnvsknTDSLQc.jpg
# 172408  ['', 'RU', '', '', 'PL', 'PL', 'PL']  /pSACmZulLFx1WsdcfqhaY3NRMLY.jpg
#
# [172409 rows x 13 columns]

# %%
sql(""" select primaryname, primarytitle,category, tconst from title_principals tp
    join name_basics using (nconst)
    join title_basics tb using (tconst)
    where category like '%actor%'
    
    
    
    """)
# Out:
#                  primaryName           primaryTitle category     tconst
# 0           Jochen Schroeder         Dabbel Trabbel    actor  tt0083781
# 1              Eberhard Feik         Dabbel Trabbel    actor  tt0083781
# 2            Anton Rattinger         Dabbel Trabbel    actor  tt0083781
# 3                 Phil Adamo         Dabbel Trabbel    actor  tt0083781
# 4         Hagen Müller-Stahl         Dabbel Trabbel    actor  tt0083781
# ...                      ...                    ...      ...        ...
# 2529409             Bo Stone           Abstractions    actor  tt9819664
# 2529410        Eijirô Arashi  Kanatehon Chushingura    actor  tt9819932
# 2529411      Masahiro Makino  Kanatehon Chushingura    actor  tt9819932
# 2529412  Sen'nosuke Nakamura  Kanatehon Chushingura    actor  tt9819932
# 2529413     Matsunosuke Onoe  Kanatehon Chushingura    actor  tt9819932
#
# [2529414 rows x 4 columns]

# %% [markdown]
# tentative avec actors

# %%
sql("""    
    
    select distinct
    Tconst as tconst,
    tb.primaryTitle as Title,
    tb.genres as Genres,
    startYear as Year,
    runtimeMinutes as Runtime,
    nb.primaryName as Director,
    t.overview as Resume,
    tr.averageRating as Rating,
    tr.numVotes as Votes,
    t.Budget as Budget,
    t.Revenue as Revenue,
    production_companies_name as ProductionCompanies,
    production_companies_country as ProductionCountries,
    t.poster_path as Poster
    from title_basics tb
    join title_akas ta on tconst = titleId
    join title_crew using (tconst)
    join name_basics nb on directors = nconst
    join tmdb t on t.imdb_id = tb.tconst
    join title_ratings tr on tb.tconst = tr.tconst
    
    ORDER BY Revenue desc
    
    """)
# Out:
#             tconst                                       Title  \
# 0        tt0499549                                      Avatar
# 1        tt1630029                    Avatar: The Way of Water
# 2        tt0120338                                     Titanic
# 3        tt2488496  Star Wars: Episode VII - The Force Awakens
# 4       tt10872600                     Spider-Man: No Way Home
# ...            ...                                         ...
# 172404   tt9466814                                       Cobra
# 172405   tt9472318                                  Üres lovak
# 172406   tt9477338                   Detective Dee's Hell Road
# 172407   tt9701598              The Return of the Yuletide Kid
# 172408   tt9732214                                La rivincita
#
#                           Genres  Year Runtime            Director  \
# 0       Action,Adventure,Fantasy  2009     162       James Cameron
# 1       Action,Adventure,Fantasy  2022     192       James Cameron
# 2                  Drama,Romance  1997     194       James Cameron
# 3        Action,Adventure,Sci-Fi  2015     138         J.J. Abrams
# 4       Action,Adventure,Fantasy  2021     148           Jon Watts
# ...                          ...   ...     ...                 ...
# 172404     Action,Crime,Thriller  2022     183  R. Ajay Gnanamuthu
# 172405                 Biography  2019      67       Péter Lichter
# 172406          Action,Adventure  2018      97            Huang He
# 172407                    Comedy  2019      70    Anthony Richards
# 172408              Comedy,Drama  2020      \N         Leo Muscato
#
#                                                    Resume  Rating    Votes  \
# 0       In the 22nd century, a paraplegic Marine is di...     7.9  1431034
# 1       Set more than a decade after the events of the...     7.5   534303
# 2       101-year-old Rose DeWitt Bukater tells the sto...     7.9  1339709
# 3       Thirty years after defeating the Galactic Empi...     7.7   999995
# 4       Peter Parker is unmasked and no longer able to...     8.2   952090
# ...                                                   ...     ...      ...
# 172404  A genius mathematician doubles up as a hit man...     5.9     9926
# 172405  If this is heaven, bring on the afterlife! The...     7.1       65
# 172406  Detective Dee is pardoned of prison by the emp...     6.0       62
# 172407  The Christmas Kid stars Craig Roberts (Red Oak...     4.4       52
# 172408  In a time of financial precariousness and desc...     6.4       47
#
#            Budget     Revenue  \
# 0       237000000  2923706026
# 1       460000000  2319331580
# 2       200000000  2264162353
# 3       245000000  2068223624
# 4       200000000  1921847111
# ...           ...         ...
# 172404          0           0
# 172405          0           0
# 172406          0           0
# 172407          0           0
# 172408          0           0
#
#                                       ProductionCompanies  \
# 0       ['Dune Entertainment', 'Lightstorm Entertainme...
# 1       ['20th Century Studios', 'Lightstorm Entertain...
# 2       ['Paramount', '20th Century Fox', 'Lightstorm ...
# 3                         ['Lucasfilm Ltd.', 'Bad Robot']
# 4       ['Marvel Studios', 'Pascal Pictures', 'Columbi...
# ...                                                   ...
# 172404                           ['Seven Screen Studios']
# 172405                                        ['Mindwax']
# 172406                                                 []
# 172407                                ['Red Union Films']
# 172408                     ['Altre Storie', 'RAI Cinema']
#
#              ProductionCountries                            Poster
# 0       ['US', 'US', 'US', 'GB']  /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg
# 1                           None  /t6HIqrRAclMCA60NsSmeqe9RmNV.jpg
# 2             ['US', 'US', 'US']  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 3                           None  /wqnLdwVXoBjKibFRR5U3y0aDUhs.jpg
# 4             ['US', 'US', 'US']  /uJYYizSuA9Y3DCs0qS4qWvHfZg4.jpg
# ...                          ...                               ...
# 172404                    ['IN']  /eriBjgwmiXWqKKZxciLQiWgof1K.jpg
# 172405                    ['HU']  /ddYsXNgAohtvHiEYYZcrRUOuDl3.jpg
# 172406                        []  /tPkPlaY34JruYWMJe77jfiiS0Wy.jpg
# 172407                      ['']  /jIl2FSK5P1LHrQhIBBEvdVMmJgn.jpg
# 172408              ['IT', 'IT']  /lUpD76OFe8tTirKAEQienq54F0d.jpg
#
# [172409 rows x 14 columns]
